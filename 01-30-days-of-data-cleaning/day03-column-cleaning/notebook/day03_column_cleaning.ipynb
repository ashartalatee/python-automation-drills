# %%
import pandas as pd
from script.clean_columns import clean_column_names

#Load dataset
df = pd.read_csv("../dataset/hari3_dataset.csv")
print("Data Mentah:")
print(df.head())
print("\nKolom Mentah:")
print(df.columns)

# Bersihkan nama kolom
df_clean = clean_column_names(df)
print("\nKolom Setelah Cleaning:")
print(df_clean.columns)

# Simpan hasil
df_clean.to_csv("../output/cleaned_day03.csv", index=False)
print("\n File cleaned_day03.csv berhasil dibuat di folder output/")
