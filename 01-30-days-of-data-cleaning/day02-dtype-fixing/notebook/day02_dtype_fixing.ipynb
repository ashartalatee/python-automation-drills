# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../dataset/hari2_dataset.csv")
print("Data Mentah:")
print(df)
print("\nTipe data awal:")
print(df.dtypes)

# Import script cleaning
from script.clean_dtype import clean_dtypes

# Bersihkan dtype
df_clean = clean_dtypes(df)

# Tampilkan hasil
print("\nData Setelah Cleaning:")
print(df_clean)
print("\nTipe data setelah cleaning:")
print(df_clean.dtypes)

# Simpan hasil
df_clean.to_csv("../output/cleaned_day02.csv", index=False)
print("\n✅ File cleaned_day02.csv berhasil dibuat di folder output/")
