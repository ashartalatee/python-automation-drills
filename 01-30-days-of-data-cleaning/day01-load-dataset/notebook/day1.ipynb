# %%
import pandas as pd

df = pd.read_csv("../dataset/day1_dataset.csv")
df.head()

# %% [markdown]
# # Day 1 — Load Dataset
#
# Dataset ini berisi transaksi customer.
# Ada beberapa kolom yang bermasalah:
#
# - Age ada string
# - Date format tidak konsisten
# - Price pakai titik ribuan
#
# Tujuan hari ini: memahami struktur dataset.
